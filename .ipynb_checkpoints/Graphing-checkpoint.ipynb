# %%
import numpy
#help(numpy.genfromtxt)

import os
distance_file = os.path.join('data','data', 'distance_data_headers.csv')
distances = numpy.genfromtxt(fname=distance_file, delimiter=',', dtype='unicode')
headers = distances[0]
data = distances[1:]
data = data.astype(numpy.float)

# %%
ls
# Out:
#  Volume in drive C is Local Disk
#  Volume Serial Number is 44C6-3E83
#
#  Directory of C:\Users\tbsha\OneDrive\Desktop\cms_workshop
#
# 08/08/2019  12:51 PM    <DIR>          .
# 08/08/2019  12:51 PM    <DIR>          ..
# 08/08/2019  12:41 PM    <DIR>          .ipynb_checkpoints
# 08/08/2019  11:39 AM               619 benzene.xyz
# 08/08/2019  11:40 AM             2,471 buckminsterfullerene.xyz
# 08/08/2019  11:33 AM           191,618 data.zip
# 08/08/2019  11:40 AM           355,359 distance_data_headers.csv
# 08/08/2019  11:37 AM    <DIR>          outfiles
# 08/08/2019  11:41 AM            61,568 sapt.out
# 08/08/2019  12:51 PM             6,911 Untitled.ipynb
#                6 File(s)        618,546 bytes
#                4 Dir(s)  182,492,295,168 bytes free

# %%
import matplotlib.pyplot

# %%
matplotlib.pyplot.figure()     #This initializes a new figure
matplotlib.pyplot.plot(data[:,1])

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(data[:,1])

# %%
sample = headers[1]

plt.figure()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')
fig_1 = plt.plot(data[:,1], label=sample)
plt.legend()

plt.savefig(F'{sample}.png')

# %%
sample = headers[1]

plt.figure()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')
fig_1 = plt.plot(data[:,1], label=sample)
plt.legend()

plt.savefig(F'{sample}.png', dpi=500)

# %%
plt.figure()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')
plt.plot(data[:,1], label=headers[1])
plt.plot(data[:,2], label=headers[2])
plt.legend()
plt.savefig('two_samples.png')

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(data[:,0], data[:,1])

# %%
# Out:
#   File "<ipython-input-18-cc65c1301147>", line 4
#     plt.plot(data[:,0], data[:,1]
#                                  ^
# SyntaxError: unexpected EOF while parsing
